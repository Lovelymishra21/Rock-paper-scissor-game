# %%
def get_player_choice(player_name):
    while True:
        choice = input(f"{player_name}, choose rock (R), paper (P), or scissors (S): ").upper()
        if choice in ["R", "P", "S"]:
            return choice
        else:
            print("Invalid choice. Please enter R, P, or S.")

def determine_winner(player1_choice, player2_choice):
    if player1_choice == player2_choice:
        return "Tie"

    if (player1_choice == "R" and player2_choice == "S") or \
            (player1_choice == "P" and player2_choice == "R") or \
            (player1_choice == "S" and player2_choice == "P"):
        return "Player 1"

    return "Player 2"

# Play the game for 10 rounds
rounds = 10
player1_score = 0
player2_score = 0

print("Let's play Rock-Paper-Scissors!")

for round in range(1, rounds + 1):
    print(f"\nRound {round}:")
    player1_choice = get_player_choice("Player 1")
    player2_choice = get_player_choice("Player 2")

    winner = determine_winner(player1_choice, player2_choice)

    if winner == "Player 1":
        player1_score += 1
        print("Player 1 wins this round!")
    elif winner == "Player 2":
        player2_score += 1
        print("Player 2 wins this round!")
    else:
        print("It's a tie for this round!")

# Determine the overall winner
print("\nGame Over!")
print(f"\nPlayer 1 Score: {player1_score}")
print(f"Player 2 Score: {player2_score}")

if player1_score > player2_score:
    print("Player 1 wins the game!")
elif player2_score > player1_score:
    print("Player 2 wins the game!")
else:
    print("It's a tie! No overall winner.")
# Out:
# Let's play Rock-Paper-Scissors!
#
# Round 1:
# Player 1, choose rock (R), paper (P), or scissors (S): R
# Player 2, choose rock (R), paper (P), or scissors (S): P
# Player 2 wins this round!
#
# Round 2:
# Player 1, choose rock (R), paper (P), or scissors (S): R
# Player 2, choose rock (R), paper (P), or scissors (S): S
# Player 1 wins this round!
#
# Round 3:
# Player 1, choose rock (R), paper (P), or scissors (S): P
# Player 2, choose rock (R), paper (P), or scissors (S): R
# Player 1 wins this round!
#
# Round 4:
# Player 1, choose rock (R), paper (P), or scissors (S): R
# Player 2, choose rock (R), paper (P), or scissors (S): S
# Player 1 wins this round!
#
# Round 5:
# Player 1, choose rock (R), paper (P), or scissors (S): S
# Player 2, choose rock (R), paper (P), or scissors (S): P
# Player 1 wins this round!
#
# Round 6:
# Player 1, choose rock (R), paper (P), or scissors (S): S
# Player 2, choose rock (R), paper (P), or scissors (S): R
# Player 2 wins this round!
#
# Round 7:
# Player 1, choose rock (R), paper (P), or scissors (S): S
# Player 2, choose rock (R), paper (P), or scissors (S): P
# Player 1 wins this round!
#
# Round 8:
# Player 1, choose rock (R), paper (P), or scissors (S): R
# Player 2, choose rock (R), paper (P), or scissors (S): P
# Player 2 wins this round!
#
# Round 9:
# Player 1, choose rock (R), paper (P), or scissors (S): R
# Player 2, choose rock (R), paper (P), or scissors (S): S
# Player 1 wins this round!
#
# Round 10:
# Player 1, choose rock (R), paper (P), or scissors (S): P
# Player 2, choose rock (R), paper (P), or scissors (S): S
# Player 2 wins this round!
#
# Game Over!
#
# Player 1 Score: 6
# Player 2 Score: 4
# Player 1 wins the game!
